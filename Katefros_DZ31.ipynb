# %%
import pandas as pd

horse = pd.read_csv('horse_data.csv', na_values = '?')
new_horse = horse.iloc[:, [0, 1, 3, 4, 5, 6, 10, 22]]
new_horse.columns = ['surgery', 'Age', 'rectal_temperature', 'pulse', 'respiratory_rate', 'temperature_of_extremities', 'pain', 'outcome']
new_horse.head()
# Out:
#    surgery  Age  rectal_temperature  pulse  respiratory_rate  \
# 0      1.0    1                39.2   88.0              20.0
# 1      2.0    1                38.3   40.0              24.0
# 2      1.0    9                39.1  164.0              84.0
# 3      2.0    1                37.3  104.0              35.0
# 4      2.0    1                 NaN    NaN               NaN
#
#    temperature_of_extremities  pain  outcome
# 0                         NaN   3.0      3.0
# 1                         1.0   3.0      1.0
# 2                         4.0   2.0      2.0
# 3                         NaN   NaN      2.0
# 4                         2.0   2.0      1.0

# %% [markdown]
# #### Общая статистика датафрейма

# %%
new_horse.describe()
# Out:
#           surgery        Age  rectal_temperature       pulse  \
# count  298.000000  299.00000          239.000000  275.000000
# mean     1.395973    1.64214           38.166527   71.934545
# std      0.489881    2.17730            0.733508   28.680522
# min      1.000000    1.00000           35.400000   30.000000
# 25%      1.000000    1.00000           37.800000   48.000000
# 50%      1.000000    1.00000           38.200000   64.000000
# 75%      2.000000    1.00000           38.500000   88.000000
# max      2.000000    9.00000           40.800000  184.000000
#
#        respiratory_rate  temperature_of_extremities        pain     outcome
# count        241.000000                  243.000000  244.000000  298.000000
# mean          30.427386                    2.345679    2.942623    1.550336
# std           17.678256                    1.046369    1.303993    0.737967
# min            8.000000                    1.000000    1.000000    1.000000
# 25%           18.000000                    1.000000    2.000000    1.000000
# 50%           24.000000                    3.000000    3.000000    1.000000
# 75%           36.000000                    3.000000    4.000000    2.000000
# max           96.000000                    4.000000    5.000000    3.000000

# %% [markdown]
# #### Доля пропусков в столбцах

# %%
(new_horse.isna().mean() * 100).round(2)
# Out:
# surgery                        0.33
# Age                            0.00
# rectal_temperature            20.07
# pulse                          8.03
# respiratory_rate              19.40
# temperature_of_extremities    18.73
# pain                          18.39
# outcome                        0.33
# dtype: float64

# %% [markdown]
# #### Фильтр на пустое значение в столбце Операция

# %%
new_horse.loc[pd.isnull(new_horse.surgery), :]
# Out:
#      surgery  Age  rectal_temperature  pulse  respiratory_rate  \
# 131      NaN    1                38.0   48.0              20.0
#
#      temperature_of_extremities  pain  outcome
# 131                         3.0   4.0      NaN

# %% [markdown]
# #### Замена пустого значения в операции на "Нет инфо"

# %%
new_horse['surgery'].fillna('no info', inplace = True)
# Out:
# D:\Python\anaconda\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %% [markdown]
# #### Ректальная температура

# %%
# найдем выбросы по графе ректальная температура
q1 = new_horse['rectal_temperature'].quantile(0.25)
q3 = new_horse['rectal_temperature'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr) 
upper_bound = q3 + (1.5 * iqr)
remove_outliers = new_horse[new_horse['rectal_temperature'].between(lower_bound, upper_bound, inclusive=True)].sort_values('rectal_temperature')
remove_outliers
# Out:
#     surgery  Age  rectal_temperature  pulse  respiratory_rate  \
# 112       1    1                36.8   60.0              28.0
# 276       2    1                36.9   50.0              40.0
# 291       1    1                37.0   66.0              20.0
# 69        2    1                37.0   60.0              20.0
# 262       1    1                37.1   75.0              36.0
# ..      ...  ...                 ...    ...               ...
# 119       1    1                39.4   54.0              66.0
# 286       2    9                39.5   84.0              30.0
# 161       2    1                39.5   60.0              10.0
# 230       2    1                39.5   92.0              28.0
# 116       2    1                39.5    NaN               NaN
#
#      temperature_of_extremities  pain  outcome
# 112                         NaN   NaN      2.0
# 276                         2.0   1.0      1.0
# 291                         1.0   4.0      2.0
# 69                          3.0   3.0      3.0
# 262                         NaN   4.0      2.0
# ..                          ...   ...      ...
# 119                         1.0   2.0      1.0
# 286                         NaN   NaN      1.0
# 161                         3.0   3.0      1.0
# 230                         3.0   5.0      2.0
# 116                         3.0   3.0      3.0
#
# [225 rows x 8 columns]

# %%
# информация о выбросах по графе ректальная температура
pd.concat([new_horse, remove_outliers]).drop_duplicates(keep=False).describe()
# Out:
#              Age  rectal_temperature       pulse  respiratory_rate  \
# count  61.000000           14.000000   50.000000         39.000000
# mean    1.655738           38.150000   82.540000         32.435897
# std     2.212730            2.048545   26.785017         13.764552
# min     1.000000           35.400000   36.000000         12.000000
# 25%     1.000000           36.425000   60.000000         24.000000
# 50%     1.000000           38.100000   80.000000         32.000000
# 75%     1.000000           39.975000  103.000000         36.000000
# max     9.000000           40.800000  140.000000         70.000000
#
#        temperature_of_extremities       pain    outcome
# count                   51.000000  50.000000  61.000000
# mean                     2.745098   3.460000   1.819672
# std                      0.890913   1.328034   0.785455
# min                      1.000000   1.000000   1.000000
# 25%                      3.000000   2.000000   1.000000
# 50%                      3.000000   4.000000   2.000000
# 75%                      3.000000   5.000000   2.000000
# max                      4.000000   5.000000   3.000000

# %%
# заполняем пустые значение в столбце ректальная температура медианой в зависимости от наличия оперативного вмешательства, возраста лошади и исхода
print(new_horse.groupby(['surgery', 'Age', 'outcome'])['rectal_temperature'].median())
new_horse['rectal_temperature'].fillna(new_horse.groupby(['surgery', 'Age', 'outcome'])['rectal_temperature'].transform('median'), inplace = True)
# Out:
# surgery  Age  outcome
# 1.0      1    1.0        38.20
#               2.0        38.00
#               3.0        38.00
#          9    1.0        38.25
#               2.0        38.80
#               3.0        39.70
# 2.0      1    1.0        38.20
#               2.0        37.85
#               3.0        38.20
#          9    1.0        38.80
#               2.0        38.00
# Name: rectal_temperature, dtype: float64
# D:\Python\anaconda\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %% [markdown]
# #### Пульс

# %%
# фильтр на пустое значение в столбце Пульс
new_horse.loc[pd.isnull(new_horse.pulse), :].head()
# Out:
#    surgery  Age  rectal_temperature  pulse  respiratory_rate  \
# 4        2    1                38.2    NaN               NaN
# 27       1    1                38.0    NaN               NaN
# 51       2    1                38.2    NaN               NaN
# 55       1    1                38.2    NaN               NaN
# 57       1    1                38.0    NaN              20.0
#
#     temperature_of_extremities  pain  outcome
# 4                          2.0   2.0      1.0
# 27                         NaN   NaN      2.0
# 51                         1.0   1.0      1.0
# 55                         NaN   NaN      1.0
# 57                         4.0   5.0      2.0

# %%
# заполним пустые значение в графе пульс медианой в зависимости от наличия оперативного вмешательства, возраста лошади и исхода
print(new_horse.groupby(['surgery', 'Age', 'outcome'])['pulse'].median())
new_horse['pulse'].fillna(new_horse.groupby(['surgery', 'Age', 'outcome'])['pulse'].transform('median'), inplace = True)
# Out:
# surgery  Age  outcome
# 1.0      1    1.0         60.0
#               2.0         73.5
#               3.0         79.0
#          9    1.0        122.0
#               2.0        146.0
#               3.0        100.0
# 2.0      1    1.0         50.0
#               2.0         92.0
#               3.0         85.0
#          9    1.0         90.0
#               2.0         92.0
# Name: pulse, dtype: float64
# D:\Python\anaconda\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
new_horse.describe()
# Out:
#              Age  rectal_temperature       pulse  respiratory_rate  \
# count  299.00000          299.000000  299.000000        241.000000
# mean     1.64214           38.158194   71.963211         30.427386
# std      2.17730            0.661533   28.238711         17.678256
# min      1.00000           35.400000   30.000000          8.000000
# 25%      1.00000           37.850000   48.000000         18.000000
# 50%      1.00000           38.200000   64.000000         24.000000
# 75%      1.00000           38.500000   88.000000         36.000000
# max      9.00000           40.800000  184.000000         96.000000
#
#        temperature_of_extremities        pain     outcome
# count                  243.000000  244.000000  298.000000
# mean                     2.345679    2.942623    1.550336
# std                      1.046369    1.303993    0.737967
# min                      1.000000    1.000000    1.000000
# 25%                      1.000000    2.000000    1.000000
# 50%                      3.000000    3.000000    1.000000
# 75%                      3.000000    4.000000    2.000000
# max                      4.000000    5.000000    3.000000

# %% [markdown]
# #### Частота дыхания

# %%
# блоки датафрейма, в котором отсутствуют данные по частоте дыхания
new_horse.loc[pd.isnull(new_horse.respiratory_rate), :].describe()
# Out:
#              Age  rectal_temperature       pulse  respiratory_rate  \
# count  58.000000           58.000000   58.000000               0.0
# mean    1.551724           38.184483   76.301724               NaN
# std     2.044869            0.577366   24.871589               NaN
# min     1.000000           36.100000   40.000000               NaN
# 25%     1.000000           38.000000   57.000000               NaN
# 50%     1.000000           38.200000   73.500000               NaN
# 75%     1.000000           38.475000   92.000000               NaN
# max     9.000000           40.000000  146.000000               NaN
#
#        temperature_of_extremities       pain    outcome
# count                   43.000000  44.000000  58.000000
# mean                     2.348837   3.295455   1.603448
# std                      0.973059   1.456015   0.724015
# min                      1.000000   1.000000   1.000000
# 25%                      1.000000   2.000000   1.000000
# 50%                      3.000000   3.000000   1.000000
# 75%                      3.000000   5.000000   2.000000
# max                      4.000000   5.000000   3.000000

# %%
# заполняем пустые значение в графе частота дыхания медианой в зависимости от наличия оперативного вмешательства, возраста лошади
print(new_horse.groupby(['surgery', 'Age', 'outcome'])['respiratory_rate'].median())
new_horse['respiratory_rate'].fillna(new_horse.groupby(['surgery', 'Age', 'outcome'])['respiratory_rate'].transform('median'), inplace = True)
# Out:
# surgery  Age  outcome
# 1.0      1    1.0        24.0
#               2.0        26.0
#               3.0        32.0
#          9    1.0        69.0
#               2.0        48.0
#               3.0         NaN
# 2.0      1    1.0        24.0
#               2.0        30.0
#               3.0        20.0
#          9    1.0        37.0
#               2.0        28.0
# Name: respiratory_rate, dtype: float64
# D:\Python\anaconda\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
new_horse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   surgery                     299 non-null    object
#  1   Age                         299 non-null    int64
#  2   rectal_temperature          299 non-null    float64
#  3   pulse                       299 non-null    float64
#  4   respiratory_rate            298 non-null    float64
#  5   temperature_of_extremities  243 non-null    float64
#  6   pain                        244 non-null    float64
#  7   outcome                     298 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 18.8+ KB

# %%
# замена пустого значения в частоте дыхания на "Нет инфо"
# в дальнейшем эту графу можно вовсе игнорировать, т.к. ее данные не информативны в силу широкого разброса
new_horse['respiratory_rate'].fillna('no info', inplace = True)

# %% [markdown]
# #### Температура конечностей, сила болевых ощущений и исход
# по оставшимся 3-ем параметрам заполняем пропуски "Нет инфы", т.к. это категориальыне величины,
# и присвоение медианных значений нулевым показателям может существенно исказить результаты

# %%
new_horse['temperature_of_extremities'].fillna('no info', inplace = True)

# %%
new_horse['pain'].fillna('no info', inplace = True)

# %%
new_horse['outcome'].fillna('no info', inplace = True)

# %%
new_horse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   surgery                     299 non-null    object
#  1   Age                         299 non-null    int64
#  2   rectal_temperature          299 non-null    float64
#  3   pulse                       299 non-null    float64
#  4   respiratory_rate            299 non-null    object
#  5   temperature_of_extremities  299 non-null    object
#  6   pain                        299 non-null    object
#  7   outcome                     299 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 18.8+ KB

# %%
new_horse.head(20)
# Out:
#    surgery  Age  rectal_temperature  pulse respiratory_rate  \
# 0        1    1                39.2   88.0               20
# 1        2    1                38.3   40.0               24
# 2        1    9                39.1  164.0               84
# 3        2    1                37.3  104.0               35
# 4        2    1                38.2   50.0               24
# 5        1    1                37.9   48.0               16
# 6        1    1                38.0   60.0               26
# 7        2    1                38.2   80.0               36
# 8        2    9                38.3   90.0               37
# 9        1    1                38.1   66.0               12
# 10       2    1                39.1   72.0               52
# 11       1    1                37.2   42.0               12
# 12       2    9                38.0   92.0               28
# 13       1    1                38.2   76.0               28
# 14       1    1                37.6   96.0               48
# 15       1    9                38.8  128.0               36
# 16       2    1                37.5   48.0               24
# 17       1    1                37.6   64.0               21
# 18       2    1                39.4  110.0               35
# 19       1    1                39.9   72.0               60
#
#    temperature_of_extremities     pain outcome
# 0                     no info        3       3
# 1                           1        3       1
# 2                           4        2       2
# 3                     no info  no info       2
# 4                           2        2       1
# 5                           1        3       1
# 6                           3  no info       2
# 7                           3        4       3
# 8                           1        5       1
# 9                           3        3       1
# 10                          2        2       1
# 11                          2        3       1
# 12                          1        1       2
# 13                          3        3       1
# 14                          3        5       2
# 15                          3        4       2
# 16                    no info  no info       1
# 17                          1        2       1
# 18                          4  no info       1
# 19                          1        5       1
